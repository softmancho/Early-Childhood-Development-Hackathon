# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import normalize
from sklearn.preprocessing import Normalizer

# %% [markdown]
# #

# %%
data= pd.read_stata('DataDrive2030_PD_EXTERNAL.dta')

# %%
# Checking the shape of the dataset
data.shape
# Out:
# (11822, 1288)

# %%
# having a look at the complete set of features in the dataset
for i, j in enumerate(data.columns):
    print(i+1, ":", j)
# Out:
# 1 : child_id
# 2 : data_year
# 3 : data_source
# 4 : child_date
# 5 : child_age
# 6 : child_enrolment_date
# 7 : child_months_enrolment
# 8 : child_grant
# 9 : child_years_in_programme
# 10 : child_score_item_1
# 11 : child_score_item_2
# 12 : child_score_item_3
# 13 : child_score_item_4
# 14 : child_domain_1
# 15 : child_score_item_5
# 16 : child_score_item_6
# 17 : child_score_item_7
# 18 : child_score_item_8
# 19 : child_domain_2
# 20 : child_score_item_9
# 21 : child_score_item_10
# 22 : child_score_item_11
# 23 : child_score_item_12
# 24 : child_score_item_13
# 25 : child_domain_3
# 26 : child_score_item_14
# 27 : child_score_item_15
# 28 : child_score_item_16
# 29 : child_score_item_17
# 30 : child_domain_4
# 31 : child_score_item_18
# 32 : child_score_item_19
# 33 : child_score_item_20
# 34 : child_score_item_21
# 35 : child_score_item_22
# 36 : child_score_item_23
# 37 : child_domain_5
# 38 : child_height
# 39 : child_observe_attentive
# 40 : child_observe_concentrated
# 41 : child_observe_diligent
# 42 : child_observe_interested
# 43 : child_observe_total
# 44 : child_total_elom
# 45 : child_total_elom_cuts
# 46 : child_domain_1_cuts
# 47 : child_domain_2_cuts
# 48 : child_domain_3_cuts
# 49 : child_domain_4_cuts
# 50 : child_domain_5_cuts
# 51 : child_gender
# 52 : child_sample_wgt
# 53 : child_dob
# 54 : child_age_w2
# 55 : child_date_w2
# 56 : child_score_item_1_w2
# 57 : child_score_item_2_w2
# 58 : child_score_item_3_w2
# 59 : child_score_item_4_w2
# 60 : child_domain_1_w2
# 61 : child_score_item_5_w2
# 62 : child_score_item_6_w2
# 63 : child_score_item_7_w2
# 64 : child_score_item_8_w2
# 65 : child_domain_2_w2
# 66 : child_score_item_9_w2
# 67 : child_score_item_10_w2
# 68 : child_score_item_11_w2
# 69 : child_score_item_12_w2
# 70 : child_score_item_13_w2
# 71 : child_domain_3_w2
# 72 : child_score_item_14_w2
# 73 : child_score_item_15_w2
# 74 : child_score_item_16_w2
# 75 : child_score_item_17_w2
# 76 : child_domain_4_w2
# 77 : child_score_item_18_w2
# 78 : child_score_item_19_w2
# 79 : child_score_item_20_w2
# 80 : child_score_item_21_w2
# 81 : child_score_item_22_w2
# 82 : child_score_item_23_w2
# 83 : child_domain_5_w2
# 84 : child_total_elom_w2
# 85 : child_height_w2
# 86 : child_observe_attentive_w2
# 87 : child_observe_concentrated_w2
# 88 : child_observe_diligent_w2
# 89 : child_observe_interested_w2
# 90 : child_observe_total_w2
# 91 : child_has_sibling
# 92 : child_spectacles
# 93 : child_conditions
# 94 : child_age_group
# 95 : child_zha
# 96 : child_zha_w2
# 97 : child_stunted
# 98 : child_stunted_w2
# 99 : PD_1_INT_total_elom_CHILD
# 100 : PD_1_INT_domain_1_CHILD
# 101 : PD_1_INT_domain_2_CHILD
# 102 : PD_1_INT_domain_3_CHILD
# 103 : PD_1_INT_domain_4_CHILD
# 104 : PD_1_INT_domain_5_CHILD
# 105 : PD_2_INT_CHILD
# 106 : PD_4_INT_CHILD
# 107 : PD_1_INT_total_elom_facility
# 108 : PD_1_INT_domain_1_facility
# 109 : PD_1_INT_domain_2_facility
# 110 : PD_1_INT_domain_3_facility
# 111 : PD_1_INT_domain_4_facility
# 112 : PD_1_INT_domain_5_facility
# 113 : PD_2_INT_pc_all_ontrack_facility
# 114 : PD_3_INT_pc_ontrack_facility
# 115 : PD_4_INT_composite_facility
# 116 : PD_1_INT_total_elom_ward
# 117 : PD_1_INT_domain_1_ward
# 118 : PD_1_INT_domain_2_ward
# 119 : PD_1_INT_domain_3_ward
# 120 : PD_1_INT_domain_4_ward
# 121 : PD_1_INT_domain_5_ward
# 122 : PD_2_INT_pc_all_ontrack_ward
# 123 : PD_3_INT_pc_ontrack_ward
# 124 : PD_4_INT_composite_ward
# 125 : PD_1_INT_total_elom_dc
# 126 : PD_1_INT_domain_1_dc
# 127 : PD_1_INT_domain_2_dc
# 128 : PD_1_INT_domain_3_dc
# 129 : PD_1_INT_domain_4_dc
# 130 : PD_1_INT_domain_5_dc
# 131 : PD_2_INT_pc_all_ontrack_dc
# 132 : PD_3_INT_pc_ontrack_dc
# 133 : PD_4_INT_composite_dc
# 134 : PD_1_INT_total_elom_mn
# 135 : PD_1_INT_domain_1_mn
# 136 : PD_1_INT_domain_2_mn
# 137 : PD_1_INT_domain_3_mn
# 138 : PD_1_INT_domain_4_mn
# 139 : PD_1_INT_domain_5_mn
# 140 : PD_2_INT_pc_all_ontrack_mn
# 141 : PD_3_INT_pc_ontrack_mn
# 142 : PD_4_INT_composite_mn
# 143 : PD_1_INT_total_facility
# 144 : PD_1_INT_total_ward
# 145 : PD_1_INT_total_mn
# 146 : PD_1_INT_total_dc
# 147 : id_mn_best
# 148 : prov_best
# 149 : id_dc_best
# 150 : dc_best
# 151 : mn_best
# 152 : ward_best
# 153 : id_enumerator
# 154 : id_facility
# 155 : pqa_date
# 156 : pqa_class_age
# 157 : pqa_class_age_1
# 158 : pqa_class_age_2
# 159 : pqa_class_age_3
# 160 : pqa_class_age_4
# 161 : pqa_class_age_5
# 162 : pqa_class_age_6
# 163 : pqa_class_assistants
# 164 : pqa_environment_areas
# 165 : pqa_environment_variety
# 166 : pqa_environment_appropriate
# 167 : pqa_environment_accessible
# 168 : pqa_environment_open
# 169 : pqa_environment_outdoor
# 170 : pqa_score_environment
# 171 : pqa_assessment_observation
# 172 : pqa_assessment_systematic
# 173 : pqa_score_assessment
# 174 : pqa_relationships_peers
# 175 : pqa_relationships_staff
# 176 : pqa_relationships_acknowledge
# 177 : pqa_relationships_discipline
# 178 : pqa_score_relationships
# 179 : pqa_curriculum_ncf
# 180 : pqa_curriculum_plan
# 181 : pqa_curriculum_balance
# 182 : pqa_curriculum_numeracy
# 183 : pqa_curriculum_literacy
# 184 : pqa_score_curriculum
# 185 : pqa_teaching_choice
# 186 : pqa_teaching_engagement
# 187 : pqa_teaching_participation
# 188 : pqa_teaching_questions
# 189 : pqa_teaching_support
# 190 : pqa_score_teaching
# 191 : pqa_class
# 192 : pra_free_play
# 193 : pra_free_play_outdoor
# 194 : pra_groupings
# 195 : pra_groupings_1
# 196 : pra_groupings_2
# 197 : pra_groupings_3
# 198 : pra_groupings_4
# 199 : pra_groupings_5
# 200 : pra_engaged
# 201 : pra_plans
# 202 : pra_plans_1
# 203 : pra_plans_2
# 204 : pra_plans_3
# 205 : pra_plans_0
# 206 : pra_gender
# 207 : pra_experience
# 208 : pra_class_present
# 209 : pra_date
# 210 : pra_class_size
# 211 : pra_class_attendance
# 212 : pra_class_attendance_precovid
# 213 : pra_class_size_large
# 214 : pra_cohort
# 215 : pra_cohort_0
# 216 : pra_cohort_1
# 217 : pra_cohort_2
# 218 : pra_cohort_3
# 219 : pra_cohort_4
# 220 : pra_cohort_5
# 221 : pra_cohort_6
# 222 : pra_class_language
# 223 : pra_plan_4yrs
# 224 : pra_plan_4yrs_1
# 225 : pra_plan_4yrs_2
# 226 : pra_plan_4yrs_3
# 227 : pra_plan_4yrs_4
# 228 : pra_plan_4yrs_97
# 229 : pra_plan_ncf
# 230 : pra_plan_5yrs
# 231 : pra_plan_5yrs_1
# 232 : pra_plan_5yrs_2
# 233 : pra_plan_5yrs_3
# 234 : pra_plan_5yrs_4
# 235 : pra_plan_5yrs_5
# 236 : pra_plan_5yrs_97
# 237 : pra_plan_approved
# 238 : pra_plan_4yrsother
# 239 : pra_plan_5yrsother
# 240 : pra_job
# 241 : pra_clearance_police
# 242 : pra_clearance_ncp
# 243 : pra_salary
# 244 : pra_paid
# 245 : pra_breadwinner
# 246 : pra_hhsize
# 247 : pra_education
# 248 : pra_qualification
# 249 : pra_qualification_1
# 250 : pra_qualification_2
# 251 : pra_qualification_3
# 252 : pra_qualification_4
# 253 : pra_qualification_5
# 254 : pra_qualification_6
# 255 : pra_qualification_7
# 256 : pra_qualification_97
# 257 : pra_qualification_0
# 258 : pra_educationother
# 259 : pra_qualificationother
# 260 : pra_previous
# 261 : pra_ncf_training
# 262 : pra_ncf_trainer
# 263 : pra_ncf_trainer_1
# 264 : pra_ncf_trainer_2
# 265 : pra_ncf_trainer_3
# 266 : pra_ncf_trainer_4
# 267 : pra_ncf_trainer_5
# 268 : pra_ncf_trainer_97
# 269 : pra_ncf_trainerother
# 270 : pra_learnership
# 271 : pra_training
# 272 : pra_training_1
# 273 : pra_training_2
# 274 : pra_training_3
# 275 : pra_training_4
# 276 : pra_training_5
# 277 : pra_training_6
# 278 : pra_training_0
# 279 : pra_special_training
# 280 : pra_special_referrals
# 281 : pra_online_training
# 282 : pra_online_training_details
# 283 : pra_motivate_support
# 284 : pra_motivate_recognition
# 285 : pra_motivate_mentoring
# 286 : pra_agency_choice
# 287 : pra_agency_explore
# 288 : pra_agency_questions
# 289 : pra_agency_understand
# 290 : pra_agency_play
# 291 : pra_agency_learn
# 292 : pra_agency_order
# 293 : pra_shape
# 294 : pra_measure_rectangle_length
# 295 : pra_measure_rectangle_width
# 296 : pra_measure_lshape_length_1
# 297 : pra_measure_lshape_width_1
# 298 : pra_measure_lshape_length_2
# 299 : pra_measure_lshape_width_2
# 300 : pra_measure_circle_diameter
# 301 : pra_class_space
# 302 : pra_class_space_small
# 303 : pra_class_space_large
# 304 : pra_parent_enrolment
# 305 : pra_meetings_per_week
# 306 : pra_on_time
# 307 : pra_class_space_2
# 308 : pra_materials_kit
# 309 : pra_materials_makefind
# 310 : pra_materials_donated
# 311 : pra_materials_library
# 312 : pra_adequacy_materials
# 313 : pra_parent_meeting
# 314 : pra_parent_regular_attendance
# 315 : pra_parent_same_attendance
# 316 : pra_dob
# 317 : pra_subsidy
# 318 : pra_grade
# 319 : pra_cotlands_visits
# 320 : pra_cotlands_support
# 321 : pra_cotlands_attendance
# 322 : pra_lesedi_visits
# 323 : pra_lesedi_support
# 324 : pra_lesedi_attendance
# 325 : pra_ntataise_visits
# 326 : pra_ntataise_support
# 327 : pra_ntataise_attendance
# 328 : pra_tuc_training_participation
# 329 : pra_tuc_visits
# 330 : pra_tuc_support
# 331 : pra_tuc_attendance
# 332 : pra_letcee_support_cluster
# 333 : pra_letcee_support_coach
# 334 : pra_letcee_club
# 335 : pra_letcee_clubmeetings
# 336 : pra_letcee_clubattendance
# 337 : pra_letcee_clubsupport
# 338 : pra_child_practitioner_ratio
# 339 : pra_satisfaction_resources
# 340 : pra_satisfaction_support
# 341 : pra_letcee_visits
# 342 : pra_ind
# 343 : pra_language
# 344 : pri_mobile
# 345 : pri_school
# 346 : pri_holidays
# 347 : pri_days
# 348 : pri_time_open_hours
# 349 : pri_time_open_minutes
# 350 : pri_time_close_hours
# 351 : pri_time_close_minutes
# 352 : pri_calc_time_open
# 353 : pri_calc_time_close
# 354 : pri_year
# 355 : pri_separate
# 356 : pri_language
# 357 : pri_language_1
# 358 : pri_language_2
# 359 : pri_language_3
# 360 : pri_language_4
# 361 : pri_language_5
# 362 : pri_language_6
# 363 : pri_language_7
# 364 : pri_language_8
# 365 : pri_language_9
# 366 : pri_language_10
# 367 : pri_language_11
# 368 : pri_language_97
# 369 : pri_languageother
# 370 : pri_toys
# 371 : pri_aftercare
# 372 : pri_toy_members_orgs
# 373 : pri_toy_members_individuals
# 374 : pri_toy_count
# 375 : pri_fees
# 376 : pri_fees_amount
# 377 : pri_fees_free
# 378 : pri_facilities
# 379 : pri_land
# 380 : pri_facilitiesother
# 381 : pri_landother
# 382 : pri_fundingother
# 383 : pri_transport
# 384 : pri_meal
# 385 : pri_meal_1
# 386 : pri_meal_3
# 387 : pri_meal_4
# 388 : pri_meal_2
# 389 : pri_registered_partial
# 390 : pri_registered_programme
# 391 : pri_registered_npo
# 392 : pri_registered_dsd
# 393 : pri_subsidy
# 394 : pri_network
# 395 : pri_dsd_year
# 396 : pri_capacity
# 397 : pri_reason_register_year
# 398 : pri_attendance_usual
# 399 : pri_precovid_attendance
# 400 : pri_kitchen
# 401 : pri_funding_6
# 402 : pri_funding_7
# 403 : pri_funding_donations
# 404 : pri_funding_97
# 405 : pri_funding
# 406 : pri_attendance
# 407 : pri_fees_exceptions
# 408 : pri_fees_paid_proportion
# 409 : pri_amount_funding_dsd
# 410 : pri_amount_funding_dbe
# 411 : pri_amount_funding_doh
# 412 : pri_amount_funding_donations
# 413 : pri_amount_funding_fundraising
# 414 : pri_amount_funding_other
# 415 : pri_amount_funding_fees
# 416 : pri_date
# 417 : pri_education
# 418 : pri_qualification
# 419 : pri_qualification_1
# 420 : pri_qualification_2
# 421 : pri_qualification_3
# 422 : pri_qualification_4
# 423 : pri_qualification_5
# 424 : pri_qualification_6
# 425 : pri_qualification_7
# 426 : pri_qualification_97
# 427 : pri_qualification_0
# 428 : pri_qualificationother
# 429 : pri_confirm_time_open
# 430 : pri_confirm_time_close
# 431 : pri_founder
# 432 : pri_founderother
# 433 : pri_same_language
# 434 : pri_location
# 435 : pri_locationother
# 436 : pri_library
# 437 : pri_confirm_subsidy
# 438 : pri_dsd_conditional
# 439 : pri_dsd_conditional_1
# 440 : pri_dsd_conditional_2
# 441 : pri_dsd_conditional_3
# 442 : pri_dsd_conditional_4
# 443 : pri_dsd_conditional_5
# 444 : pri_dsd_conditional_6
# 445 : pri_dsd_conditional_7
# 446 : pri_dsd_conditional_8
# 447 : pri_dsd_conditional_9
# 448 : pri_dsd_conditional_10
# 449 : pri_dsd_conditional_97
# 450 : pri_dsd_conditional_other
# 451 : pri_dsd_previous
# 452 : pri_dsd_unregistered
# 453 : pri_dsd_unregistered_1
# 454 : pri_dsd_unregistered_2
# 455 : pri_dsd_unregistered_3
# 456 : pri_dsd_unregistered_4
# 457 : pri_dsd_unregistered_5
# 458 : pri_dsd_unregistered_6
# 459 : pri_dsd_unregistered_7
# 460 : pri_dsd_unregistered_8
# 461 : pri_dsd_unregistered_9
# 462 : pri_dsd_unregistered_10
# 463 : pri_dsd_unregistered_11
# 464 : pri_dsd_unregistered_12
# 465 : pri_dsd_unregistered_13
# 466 : pri_dsd_unregistered_97
# 467 : pri_dsd_unregistered_other
# 468 : pri_registered_health
# 469 : pri_zoning
# 470 : pri_registered_cipc
# 471 : pri_network_type
# 472 : pri_network_type_1
# 473 : pri_network_type_2
# 474 : pri_network_type_3
# 475 : pri_network_type_97
# 476 : pri_name_network_forum
# 477 : pri_email_network_forum
# 478 : pri_name_network_ngo
# 479 : pri_name_network_alliance
# 480 : pri_name_network_other
# 481 : pri_children_4_6_years
# 482 : pri_difficult_see
# 483 : pri_difficult_hear
# 484 : pri_difficult_walk
# 485 : pri_difficult_hold
# 486 : pri_difficult_communicate
# 487 : pri_difficult_learn
# 488 : pri_support_dsd
# 489 : pri_support_dbe
# 490 : pri_support_municipality
# 491 : pri_support_ngo
# 492 : pri_firstaid
# 493 : pri_staff_employed
# 494 : pri_staff_changes_reasons
# 495 : pri_staff_changes_reasons_1
# 496 : pri_staff_changes_reasons_2
# 497 : pri_staff_changes_reasons_3
# 498 : pri_staff_changes_reasons_4
# 499 : pri_staff_changes_reasons_5
# 500 : pri_staff_changes_reasons_6
# 501 : pri_staff_changes_reasons_97
# 502 : pri_staff_changes_reasonsother
# 503 : pri_covid_staff_retrench
# 504 : pri_covid_staff_salaries
# 505 : pri_bank
# 506 : pri_money
# 507 : pri_money_1
# 508 : pri_money_2
# 509 : pri_money_3
# 510 : pri_money_97
# 511 : pri_money__1
# 512 : pri_funding_1
# 513 : pri_funding_2
# 514 : pri_funding_3
# 515 : pri_funding_4
# 516 : pri_funding_5
# 517 : pri_funding_none
# 518 : pri_moneyother
# 519 : pri_funding_salary
# 520 : pri_funding_salary_1
# 521 : pri_funding_salary_2
# 522 : pri_funding_salary_3
# 523 : pri_funding_salary_4
# 524 : pri_funding_salary_97
# 525 : pri_funding_salary_0
# 526 : pri_funding_food
# 527 : pri_funding_salaryother
# 528 : pri_fees_amount_0_1
# 529 : pri_fees_amount_2_3
# 530 : pri_fees_exceptions_other
# 531 : pri_expense_food
# 532 : pri_expense_staff
# 533 : pri_expense_rent
# 534 : pri_expense_materials
# 535 : pri_expense_maintenance
# 536 : pri_expense_admin
# 537 : pri_expense_other
# 538 : pri_expenseother
# 539 : pri_covid_fund_applied
# 540 : pri_covid_fund_received
# 541 : pri_clinic_time
# 542 : pri_clinic_travel
# 543 : pri_clinic_travel_1
# 544 : pri_clinic_travel_2
# 545 : pri_clinic_travel_3
# 546 : pri_clinic_travel_4
# 547 : pri_clinic_travel_5
# 548 : pri_clinic_travel_97
# 549 : pri_health_1
# 550 : pri_health_2
# 551 : pri_health_3
# 552 : pri_health_4
# 553 : pri_health_5
# 554 : pri_health_97
# 555 : pri_health_0
# 556 : pri_clinic_travelother
# 557 : pri_covid_awareness
# 558 : pri_covid_awareness_1
# 559 : pri_covid_awareness_2
# 560 : pri_covid_awareness_3
# 561 : pri_covid_awareness_4
# 562 : pri_covid_awareness_97
# 563 : pri_covid_precautions
# 564 : pri_covid_precautions_1
# 565 : pri_covid_precautions_2
# 566 : pri_covid_precautions_3
# 567 : pri_covid_precautions_4
# 568 : pri_covid_precautions_5
# 569 : pri_covid_precautions_6
# 570 : pri_covid_precautions_97
# 571 : pri_covid_awareness_other
# 572 : pri_covid_precautions_other
# 573 : pri_food_parents_breakfast
# 574 : pri_food_parents_morning
# 575 : pri_food_parents_lunch
# 576 : pri_food_parents_afternoon
# 577 : pri_food_guidance
# 578 : pri_food_type
# 579 : pri_food_type_1
# 580 : pri_food_type_2
# 581 : pri_food_type_3
# 582 : pri_food_type_4
# 583 : pri_food_type_5
# 584 : pri_food_type_0
# 585 : pri_food_donation
# 586 : pri_food_donor
# 587 : pri_food_donor_1
# 588 : pri_food_donor_2
# 589 : pri_food_donor_3
# 590 : pri_food_donor_4
# 591 : pri_food_donor_97
# 592 : pri_food_donorother
# 593 : pri_refrigerator
# 594 : pri_garden
# 595 : pri_meal_prep
# 596 : pri_parents_frequency
# 597 : pri_parents_contact
# 598 : pri_parents_activities
# 599 : pri_records
# 600 : pri_records_1
# 601 : pri_records_2
# 602 : pri_records_3
# 603 : pri_records_4
# 604 : pri_records_5
# 605 : pri_records_0
# 606 : pri_support
# 607 : pri_support_provider
# 608 : pri_support_provider_1
# 609 : pri_support_provider_2
# 610 : pri_support_provider_3
# 611 : pri_support_provider_4
# 612 : pri_support_provider_5
# 613 : pri_support_provider_97
# 614 : pri_support_providerother
# 615 : pri_support_frequency
# 616 : pri_fees_amount_4_6
# 617 : pri_library_material_1
# 618 : pri_library_material_2
# 619 : pri_library_material_3
# 620 : pri_library_material_4
# 621 : pri_library_material_5
# 622 : pri_library_material_6
# 623 : pri_library_material_7
# 624 : pri_library_material_8
# 625 : pri_library_material_9
# 626 : pri_library_material_10
# 627 : pri_library_material_11
# 628 : pri_library_material_12
# 629 : pri_learners_n_gr_r
# 630 : pri_learners_n_gr_1
# 631 : pri_learners_n_gr_2
# 632 : pri_learners_n_gr_3
# 633 : pri_learners_n_gr_4
# 634 : pri_learners_n_gr_5
# 635 : pri_learners_n_gr_6
# 636 : pri_learners_n_gr_7
# 637 : pri_internet
# 638 : pri_internet_source
# 639 : pri_internet_user
# 640 : pri_internet_user_1
# 641 : pri_internet_user_2
# 642 : pri_internet_user_3
# 643 : pri_internet_user_4
# 644 : pri_fees_amount_pv
# 645 : pri_funding_subsidy
# 646 : pri_meals
# 647 : obs_firstaid
# 648 : obs_classrooms
# 649 : obs_space
# 650 : obs_area
# 651 : obs_area_1
# 652 : obs_area_2
# 653 : obs_area_3
# 654 : obs_area_4
# 655 : obs_area_5
# 656 : obs_area_6
# 657 : obs_area_7
# 658 : obs_area_8
# 659 : obs_area_0
# 660 : obs_materials
# 661 : obs_materials_1
# 662 : obs_materials_2
# 663 : obs_materials_3
# 664 : obs_materials_4
# 665 : obs_materials_5
# 666 : obs_materials_6
# 667 : obs_materials_7
# 668 : obs_materials_8
# 669 : obs_materials_9
# 670 : obs_materials_10
# 671 : obs_materials_11
# 672 : obs_materials_12
# 673 : obs_materials_13
# 674 : obs_materials_14
# 675 : obs_materials_15
# 676 : obs_materials_16
# 677 : obs_materials_17
# 678 : obs_materials_18
# 679 : obs_materials_19
# 680 : obs_materials_20
# 681 : obs_materials_97
# 682 : obs_materials_0
# 683 : obs_materialsother
# 684 : obs_accessible
# 685 : obs_books
# 686 : obs_books_age
# 687 : obs_heating_census
# 688 : obs_lighting_census
# 689 : obs_cooking_census
# 690 : obs_water
# 691 : obs_waterother
# 692 : obs_potable
# 693 : obs_handwashing
# 694 : obs_handwashing_1
# 695 : obs_handwashing_2
# 696 : obs_handwashing_3
# 697 : obs_handwashing_0
# 698 : obs_handwashing_97
# 699 : obs_toilet
# 700 : obs_toilet_1
# 701 : obs_toilet_2
# 702 : obs_toilet_3
# 703 : obs_toilet_4
# 704 : obs_toilet_5
# 705 : obs_toilet_6
# 706 : obs_toilet_7
# 707 : obs_toilet_8
# 708 : obs_toilet_0
# 709 : obs_toilet_97
# 710 : obs_toilets_children
# 711 : obs_toilets_gender
# 712 : obs_building
# 713 : obs_shared
# 714 : obs_outdoor
# 715 : obs_equipment
# 716 : obs_equipment_0
# 717 : obs_equipment_1
# 718 : obs_equipment_2
# 719 : obs_equipment_3
# 720 : obs_equipment_4
# 721 : obs_equipment_5
# 722 : obs_equipment__1
# 723 : obs_condition_equipment
# 724 : obs_fence
# 725 : obs_gate
# 726 : obs_access
# 727 : obs_date
# 728 : obs_water_running
# 729 : obs_water_running_none
# 730 : obs_handwashingother
# 731 : obs_handwashing_friendly
# 732 : obs_toilet_clean
# 733 : obs_toilet_paper
# 734 : obs_toilet_size_flush
# 735 : obs_toilet_size_flush_1
# 736 : obs_toilet_size_flush_2
# 737 : obs_toilet_size_flush_3
# 738 : obs_toilet_size_septic
# 739 : obs_toilet_size_septic_1
# 740 : obs_toilet_size_septic_2
# 741 : obs_toilet_size_septic_3
# 742 : obs_toilet_size_chemical
# 743 : obs_toilet_size_chemical_1
# 744 : obs_toilet_size_chemical_2
# 745 : obs_toilet_size_chemical_3
# 746 : obs_toilet_size_ventilation
# 747 : obs_toilet_size_ventilation_1
# 748 : obs_toilet_size_ventilation_2
# 749 : obs_toilet_size_ventilation_3
# 750 : obs_toilet_size_pit
# 751 : obs_toilet_size_pit_1
# 752 : obs_toilet_size_pit_2
# 753 : obs_toilet_size_pit_3
# 754 : obs_toilet_size_disability
# 755 : obs_toilet_size_disability_1
# 756 : obs_toilet_size_disability_2
# 757 : obs_toilet_size_disability_3
# 758 : obs_heating
# 759 : obs_lighting
# 760 : obs_cooking
# 761 : obs_electricity_working
# 762 : obs_access_disability_1
# 763 : obs_access_disability_2
# 764 : obs_access_disability_3
# 765 : obs_access_disability_4
# 766 : obs_access_disability_5
# 767 : obs_access_disability_6
# 768 : obs_access_disability_0
# 769 : obs_safety
# 770 : obs_safety_1
# 771 : obs_safety_2
# 772 : obs_safety_3
# 773 : obs_safety_4
# 774 : obs_safety_5
# 775 : obs_safety_6
# 776 : obs_safety_7
# 777 : obs_safety_8
# 778 : obs_safety_9
# 779 : obs_safety_10
# 780 : obs_safety_0
# 781 : obs_menu_display
# 782 : obs_menu_compliance
# 783 : obs_menu_same
# 784 : obs_material_display
# 785 : obs_hazard
# 786 : obs_hazard_1
# 787 : obs_hazard_2
# 788 : obs_hazard_3
# 789 : obs_hazard_4
# 790 : obs_hazard_5
# 791 : obs_hazard_6
# 792 : obs_hazard_7
# 793 : obs_hazard_8
# 794 : obs_hazard_97
# 795 : obs_hazard_0
# 796 : obs_fencing_play_area
# 797 : obs_booknumber
# 798 : obs_fencing
# 799 : obs_toilets_n_girls
# 800 : obs_toilets_n_boys
# 801 : obs_toilets_n_unisex
# 802 : obs_infrastructure
# 803 : obs_heating_1
# 804 : obs_heating_2
# 805 : obs_heating_3
# 806 : obs_heating_4
# 807 : obs_heating_5
# 808 : obs_heating_6
# 809 : obs_heating_7
# 810 : obs_heating_8
# 811 : obs_lighting_1
# 812 : obs_lighting_2
# 813 : obs_lighting_3
# 814 : obs_lighting_4
# 815 : obs_lighting_5
# 816 : obs_lighting_6
# 817 : obs_lighting_8
# 818 : obs_cooking_7
# 819 : obs_cooking_1
# 820 : obs_cooking_2
# 821 : obs_cooking_3
# 822 : obs_cooking_4
# 823 : obs_cooking_5
# 824 : obs_cooking_6
# 825 : teacher_social_peers
# 826 : teacher_social_nonaggressive
# 827 : teacher_social_cooperate
# 828 : teacher_social_assistance
# 829 : teacher_social_ideas
# 830 : teacher_social_initiative
# 831 : teacher_emotional_understand
# 832 : teacher_emotional_appropriate
# 833 : teacher_emotional_independent
# 834 : teacher_emotional_adjust
# 835 : teacher_emotional_confidence
# 836 : teacher_emotional_selfstarter
# 837 : teacher_duration
# 838 : teacher_date
# 839 : teacher_familiarity_with_child
# 840 : teacher_social_total
# 841 : teacher_selfcare_total
# 842 : teacher_social_met
# 843 : teacher_emotional_total
# 844 : teacher_emotional_met
# 845 : teacher_selfcare_met
# 846 : hle_date
# 847 : hle_caregiver_dob
# 848 : hle_caregiver_relation
# 849 : hle_burdenofcare
# 850 : hle_caregiver_postschool
# 851 : hle_time_available_weekday
# 852 : hle_time_available_weekend
# 853 : hle_picturebooks
# 854 : hle_homemade_toys
# 855 : hle_homemade_toys_string
# 856 : hle_shop_toys
# 857 : hle_shop_toys_string
# 858 : hle_objects_as_toys
# 859 : hle_objects_as_toys_string
# 860 : hle_readbooks_time
# 861 : hle_readbooks_noone
# 862 : hle_readbooks_mother
# 863 : hle_readbooks_father
# 864 : hle_readbooks_auntoruncle
# 865 : hle_readbooks_grandparent
# 866 : hle_readbooks_sibling
# 867 : hle_readbooks_other
# 868 : hle_readbooks_otherwho
# 869 : hle_stories_time
# 870 : hle_stories_noone
# 871 : hle_stories_mother
# 872 : hle_stories_father
# 873 : hle_stories_auntoruncle
# 874 : hle_stories_grandparent
# 875 : hle_stories_sibling
# 876 : hle_stories_other
# 877 : hle_stories_otherwho
# 878 : hle_sing_time
# 879 : hle_sing_noone
# 880 : hle_sing_mother
# 881 : hle_sing_father
# 882 : hle_sing_auntoruncle
# 883 : hle_sing_grandparent
# 884 : hle_sing_sibling
# 885 : hle_sing_other
# 886 : hle_sing_otherwho
# 887 : hle_outside_time
# 888 : hle_outside_noone
# 889 : hle_outside_mother
# 890 : hle_outside_father
# 891 : hle_outside_auntoruncle
# 892 : hle_outside_grandparent
# 893 : hle_outside_sibling
# 894 : hle_outside_other
# 895 : hle_outside_otherwho
# 896 : hle_play_time
# 897 : hle_play_noone
# 898 : hle_play_mother
# 899 : hle_play_father
# 900 : hle_play_auntoruncle
# 901 : hle_play_grandparent
# 902 : hle_play_sibling
# 903 : hle_play_other
# 904 : hle_play_otherwho
# 905 : hle_names_time
# 906 : hle_names_noone
# 907 : hle_names_mother
# 908 : hle_names_father
# 909 : hle_names_auntoruncle
# 910 : hle_names_grandparent
# 911 : hle_names_sibling
# 912 : hle_names_other
# 913 : hle_names_otherwho
# 914 : hle_count_time
# 915 : hle_count_noone
# 916 : hle_count_mother
# 917 : hle_count_father
# 918 : hle_count_auntoruncle
# 919 : hle_count_grandparent
# 920 : hle_count_sibling
# 921 : hle_count_other
# 922 : hle_count_otherwho
# 923 : hle_paintdraw_time
# 924 : hle_paintdraw_noone
# 925 : hle_paintdraw_mother
# 926 : hle_paintdraw_father
# 927 : hle_paintdraw_auntoruncle
# 928 : hle_paintdraw_grandparent
# 929 : hle_paintdraw_sibling
# 930 : hle_paintdraw_other
# 931 : hle_paintdraw_otherwho
# 932 : hle_ecd_howfind_1
# 933 : hle_ecd_howfind_2
# 934 : hle_ecd_howfind_3
# 935 : hle_ecd_howfind_4
# 936 : hle_ecd_howfind_5
# 937 : hle_ecd_other
# 938 : hle_ecd_reason
# 939 : hle_ecd_availability_1
# 940 : hle_ecd_availability_2
# 941 : hle_ecd_availability_3
# 942 : hle_ecd_availability_4
# 943 : hle_ecd_availability_5
# 944 : hle_ecd_availability_6
# 945 : hle_ecd_availability_other
# 946 : hle_ecd_whychoose_1
# 947 : hle_ecd_whychoose_2
# 948 : hle_ecd_whychoose_3
# 949 : hle_ecd_whychoose_4
# 950 : hle_ecd_whychoose_5
# 951 : hle_ecd_whychoose_6
# 952 : hle_ecd_reason_other
# 953 : hle_caregiver_educ
# 954 : hle_home_learning_opportunity
# 955 : hle_early_learning_resources
# 956 : hle_time_for_stimulation
# 957 : hle_books
# 958 : hle_range_play_resources
# 959 : hle_activity_score
# 960 : hle_caregiver_gender
# 961 : hle_ind
# 962 : ward_fee_m
# 963 : ward_water_tap_m
# 964 : ward_subsidy_m
# 965 : ward_transport_m
# 966 : ward_toilet_1_m
# 967 : ward_meals_m
# 968 : ward_building_con_m
# 969 : ward_fees_free_m
# 970 : ward_registered_dsd_fc_m
# 971 : ward_capacity_m
# 972 : ward_books_m
# 973 : ward_books_age_m
# 974 : ward_potable_m
# 975 : ward_separate_m
# 976 : ward_school_m
# 977 : ward_aftercare_m
# 978 : ward_firstaid_m
# 979 : ward_bank_m
# 980 : ward_count_register_all_m
# 981 : ward_count_children_present_m
# 982 : ward_count_children_usual_m
# 983 : ward_count_children_precovid_m
# 984 : ward_count_staff_cat_educ_m
# 985 : ward_count_staff_cat_prac_m
# 986 : ward_space_m
# 987 : dc_fee_m
# 988 : dc_water_tap_m
# 989 : dc_subsidy_m
# 990 : dc_transport_m
# 991 : dc_toilet_1_m
# 992 : dc_meals_m
# 993 : dc_building_con_m
# 994 : dc_fees_free_m
# 995 : dc_registered_dsd_fc_m
# 996 : dc_capacity_m
# 997 : dc_books_m
# 998 : dc_books_age_m
# 999 : dc_potable_m
# 1000 : dc_separate_m
# 1001 : dc_school_m
# 1002 : dc_aftercare_m
# 1003 : dc_firstaid_m
# 1004 : dc_bank_m
# 1005 : dc_count_register_all_m
# 1006 : dc_count_children_present_m
# 1007 : dc_count_children_usual_m
# 1008 : dc_count_children_precovid_m
# 1009 : dc_count_staff_cat_educ_m
# 1010 : dc_count_staff_cat_prac_m
# 1011 : dc_space_m
# 1012 : mn_fee_m
# 1013 : mn_water_tap_m
# 1014 : mn_subsidy_m
# 1015 : mn_transport_m
# 1016 : mn_toilet_1_m
# 1017 : mn_meals_m
# 1018 : mn_building_con_m
# 1019 : mn_fees_free_m
# 1020 : mn_registered_dsd_fc_m
# 1021 : mn_capacity_m
# 1022 : mn_books_m
# 1023 : mn_books_age_m
# 1024 : mn_potable_m
# 1025 : mn_separate_m
# 1026 : mn_school_m
# 1027 : mn_aftercare_m
# 1028 : mn_firstaid_m
# 1029 : mn_bank_m
# 1030 : mn_count_register_all_m
# 1031 : mn_count_children_present_m
# 1032 : mn_count_children_usual_m
# 1033 : mn_count_children_precovid_m
# 1034 : mn_count_staff_cat_educ_m
# 1035 : mn_count_staff_cat_prac_m
# 1036 : mn_space_m
# 1037 : prov_fee_m
# 1038 : prov_water_tap_m
# 1039 : prov_subsidy_m
# 1040 : prov_transport_m
# 1041 : prov_toilet_1_m
# 1042 : prov_meals_m
# 1043 : prov_building_con_m
# 1044 : prov_fees_free_m
# 1045 : prov_registered_dsd_fc_m
# 1046 : prov_capacity_m
# 1047 : prov_books_m
# 1048 : prov_books_age_m
# 1049 : prov_potable_m
# 1050 : prov_separate_m
# 1051 : prov_school_m
# 1052 : prov_aftercare_m
# 1053 : prov_firstaid_m
# 1054 : prov_bank_m
# 1055 : prov_count_register_all_m
# 1056 : prov_count_children_present_m
# 1057 : prov_count_children_usual_m
# 1058 : prov_count_children_precovid_m
# 1059 : prov_count_staff_cat_educ_m
# 1060 : prov_count_staff_cat_prac_m
# 1061 : prov_space_m
# 1062 : PD_1_UV_CHILD
# 1063 : PD_1_UV_domain_1_CHILD
# 1064 : PD_1_UV_domain_2_CHILD
# 1065 : PD_1_UV_domain_3_CHILD
# 1066 : PD_1_UV_domain_4_CHILD
# 1067 : PD_1_UV_domain_5_CHILD
# 1068 : PD_2_UV_CHILD
# 1069 : PD_4_UV_CHILD
# 1070 : PD_1_UV_domain_1_facility
# 1071 : PD_1_UV_domain_2_facility
# 1072 : PD_1_UV_domain_4_facility
# 1073 : PD_1_UV_domain_3_facility
# 1074 : PD_1_UV_domain_5_facility
# 1075 : PD_2_UV_pc_all_ontrack_facility
# 1076 : PD_3_UV_pc_ontrack_facility
# 1077 : PD_1_UV_total_elom_facility
# 1078 : PD_4_UV_composite_facility
# 1079 : PD_1_UV_domain_1_ward
# 1080 : PD_1_UV_domain_2_ward
# 1081 : PD_1_UV_domain_4_ward
# 1082 : PD_1_UV_domain_3_ward
# 1083 : PD_1_UV_domain_5_ward
# 1084 : PD_2_UV_pc_all_ontrack_ward
# 1085 : PD_3_UV_pc_ontrack_ward
# 1086 : PD_1_UV_total_elom_ward
# 1087 : PD_4_UV_composite_ward
# 1088 : PD_1_UV_domain_1_dc
# 1089 : PD_1_UV_domain_2_dc
# 1090 : PD_1_UV_domain_4_dc
# 1091 : PD_1_UV_domain_3_dc
# 1092 : PD_1_UV_domain_5_dc
# 1093 : PD_2_UV_pc_all_ontrack_dc
# 1094 : PD_3_UV_pc_ontrack_dc
# 1095 : PD_1_UV_total_elom_dc
# 1096 : PD_4_UV_composite_dc
# 1097 : PD_1_UV_domain_1_mn
# 1098 : PD_1_UV_domain_2_mn
# 1099 : PD_1_UV_domain_4_mn
# 1100 : PD_1_UV_domain_3_mn
# 1101 : PD_1_UV_domain_5_mn
# 1102 : PD_2_UV_pc_all_ontrack_mn
# 1103 : PD_3_UV_pc_ontrack_mn
# 1104 : PD_1_UV_total_elom_mn
# 1105 : PD_4_UV_composite_mn
# 1106 : PD_1_MV_CHILD
# 1107 : PD_1_MV_domain_1_CHILD
# 1108 : PD_1_MV_domain_2_CHILD
# 1109 : PD_1_MV_domain_3_CHILD
# 1110 : PD_1_MV_domain_4_CHILD
# 1111 : PD_1_MV_domain_5_CHILD
# 1112 : PD_2_MV_CHILD
# 1113 : PD_4_MV_CHILD
# 1114 : PD_1_MV_domain_1_facility
# 1115 : PD_1_MV_domain_2_facility
# 1116 : PD_1_MV_domain_4_facility
# 1117 : PD_1_MV_domain_3_facility
# 1118 : PD_1_MV_domain_5_facility
# 1119 : PD_2_MV_pc_all_ontrack_facility
# 1120 : PD_3_MV_pc_ontrack_facility
# 1121 : PD_1_MV_total_elom_facility
# 1122 : PD_4_MV_composite_facility
# 1123 : PD_1_MV_domain_1_ward
# 1124 : PD_1_MV_domain_2_ward
# 1125 : PD_1_MV_domain_4_ward
# 1126 : PD_1_MV_domain_3_ward
# 1127 : PD_1_MV_domain_5_ward
# 1128 : PD_2_MV_pc_all_ontrack_ward
# 1129 : PD_3_MV_pc_ontrack_ward
# 1130 : PD_1_MV_total_elom_ward
# 1131 : PD_4_MV_composite_ward
# 1132 : PD_1_MV_domain_1_dc
# 1133 : PD_1_MV_domain_2_dc
# 1134 : PD_1_MV_domain_4_dc
# 1135 : PD_1_MV_domain_3_dc
# 1136 : PD_1_MV_domain_5_dc
# 1137 : PD_2_MV_pc_all_ontrack_dc
# 1138 : PD_3_MV_pc_ontrack_dc
# 1139 : PD_1_MV_total_elom_dc
# 1140 : PD_4_MV_composite_dc
# 1141 : PD_1_MV_domain_1_mn
# 1142 : PD_1_MV_domain_2_mn
# 1143 : PD_1_MV_domain_4_mn
# 1144 : PD_1_MV_domain_3_mn
# 1145 : PD_1_MV_domain_5_mn
# 1146 : PD_2_MV_pc_all_ontrack_mn
# 1147 : PD_3_MV_pc_ontrack_mn
# 1148 : PD_1_MV_total_elom_mn
# 1149 : PD_4_MV_composite_mn
# 1150 : id_ward
# 1151 : id_prov
# 1152 : count_register_all
# 1153 : count_staff_all
# 1154 : count_children_present
# 1155 : count_children_attendance
# 1156 : count_children_precovid
# 1157 : gps
# 1158 : latitude
# 1159 : longitude
# 1160 : count_aftercare
# 1161 : count_register_gender_female
# 1162 : count_register_gender_male
# 1163 : count_register_gender_other
# 1164 : count_register_gender
# 1165 : count_register_year_2021
# 1166 : count_register_year_2020
# 1167 : count_register_year_2019
# 1168 : count_register_year_2018
# 1169 : count_register_year_2017
# 1170 : count_register_year_2016
# 1171 : count_register_year_2015
# 1172 : count_register_year_2014
# 1173 : count_register_year_2013
# 1174 : count_register_year_school
# 1175 : count_register_year_grader
# 1176 : grade_r
# 1177 : count_register_race_african
# 1178 : count_register_race_coloured
# 1179 : count_register_race_indian
# 1180 : count_register_race_white
# 1181 : count_register_race_other
# 1182 : count_register_race
# 1183 : count_staff_qual_skills
# 1184 : count_staff_qual_nqf4_5
# 1185 : count_staff_qual_nqf6_9
# 1186 : count_toilets_children
# 1187 : count_toilets_adults
# 1188 : census
# 1189 : urban
# 1190 : id_team
# 1191 : id_cluster_original
# 1192 : phase_natemis
# 1193 : quintile
# 1194 : access_disability
# 1195 : opening_hours
# 1196 : count_register_foreign
# 1197 : count_present_girls
# 1198 : count_present_boys
# 1199 : count_staff_gender_female
# 1200 : count_staff_gender_male
# 1201 : count_staff_gender_other
# 1202 : count_staff_gender
# 1203 : count_staff_contract_permanent
# 1204 : count_staff_contract_temporary
# 1205 : count_staff_contract_substitute
# 1206 : count_staff_contract
# 1207 : count_staff_time_full
# 1208 : count_staff_time_part
# 1209 : count_staff_time
# 1210 : count_staff_salary_paid
# 1211 : count_staff_salary_unpaid
# 1212 : count_staff_salary
# 1213 : count_staff_paid_practitioners
# 1214 : count_staff_paid_assistants
# 1215 : count_staff_paid_cooks
# 1216 : count_staff_paid_maintenance
# 1217 : count_staff_paid_managers
# 1218 : count_staff_paid_support
# 1219 : count_staff_paid
# 1220 : count_staff_unpaid_practitioners
# 1221 : count_staff_unpaid_assistants
# 1222 : count_staff_unpaid_cooks
# 1223 : count_staff_unpaid_maintenance
# 1224 : count_staff_unpaid_managers
# 1225 : count_staff_unpaid_support
# 1226 : count_staff_unpaid
# 1227 : count_staff_managers
# 1228 : professionals_practitioners
# 1229 : count_practitioners_all
# 1230 : count_practitioners_age_0
# 1231 : count_practitioners_age_1
# 1232 : count_practitioners_age_2
# 1233 : count_practitioners_age_3
# 1234 : count_practitioners_age_4
# 1235 : count_practitioners_age_5
# 1236 : count_practitioners_age_6
# 1237 : count_staff_cat_educator
# 1238 : health
# 1239 : healthother
# 1240 : certificate_registration_partial
# 1241 : certificate_registration_program
# 1242 : certificate_registration_npo
# 1243 : certificate_register
# 1244 : practitioner
# 1245 : other_practitioner
# 1246 : plan
# 1247 : language_child
# 1248 : language_assessment
# 1249 : count_assistants
# 1250 : duration_elom
# 1251 : programme
# 1252 : saspri_datazone_quintile
# 1253 : duration_w2
# 1254 : programme_exposure
# 1255 : urban_distance
# 1256 : urban_census
# 1257 : facility_type
# 1258 : language_child_friends
# 1259 : library_access
# 1260 : rating
# 1261 : sanitation_educators
# 1262 : sanitation_educators_1
# 1263 : sanitation_educators_2
# 1264 : sanitation_educators_3
# 1265 : sanitation_educators_96
# 1266 : sanitation_learners
# 1267 : sanitation_learners_3
# 1268 : positionother
# 1269 : positionotherreason
# 1270 : gr_r
# 1271 : gr_ecd
# 1272 : gr_c1
# 1273 : gr_c2
# 1274 : gr_c3
# 1275 : gr_1_tt
# 1276 : sef_ind
# 1277 : ses_cat
# 1278 : language_match
# 1279 : elp_ind
# 1280 : gps_ind
# 1281 : pre_covid
# 1282 : ses_proxy
# 1283 : quintile_used
# 1284 : id_facility_n
# 1285 : id_ward_n
# 1286 : id_mn_n
# 1287 : id_dc_n
# 1288 : id_prov_n

# %%
scores_df= data[['child_score_item_1', 'child_score_item_2', 'child_score_item_3',
       'child_score_item_4', 'child_score_item_5',
       'child_score_item_6', 'child_score_item_7', 'child_score_item_8',
       'child_score_item_9', 'child_score_item_10',
       'child_score_item_11', 'child_score_item_12', 'child_score_item_13',
       'child_score_item_14', 'child_score_item_15',
       'child_score_item_16', 'child_score_item_17', 
       'child_score_item_18', 'child_score_item_19', 'child_score_item_20',
       'child_score_item_21', 'child_score_item_22', 'child_score_item_23',
       ]]

domain_df= data[[
    'child_domain_1', 'child_domain_2', 'child_domain_3', 
    'child_domain_4', 'child_domain_5'
]]

# %%
scores_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11822 entries, 0 to 11821
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   child_score_item_1   11822 non-null  float64
#  1   child_score_item_2   11822 non-null  float64
#  2   child_score_item_3   11822 non-null  float64
#  3   child_score_item_4   11822 non-null  float64
#  4   child_score_item_5   11822 non-null  float64
#  5   child_score_item_6   11817 non-null  float64
#  6   child_score_item_7   11819 non-null  float64
#  7   child_score_item_8   11822 non-null  float64
#  8   child_score_item_9   11822 non-null  float64
#  9   child_score_item_10  11774 non-null  float64
#  10  child_score_item_11  11822 non-null  float64
#  11  child_score_item_12  11822 non-null  float64
#  12  child_score_item_13  11822 non-null  float64
#  13  child_score_item_14  11822 non-null  float64
#  14  child_score_item_15  11765 non-null  float64
#  15  child_score_item_16  11815 non-null  float64
#  16  child_score_item_17  11821 non-null  float64
#  17  child_score_item_18  11822 non-null  float64
#  18  child_score_item_19  11822 non-null  float64
#  19  child_score_item_20  11822 non-null  float64
#  20  child_score_item_21  11822 non-null  float64
#  21  child_score_item_22  11822 non-null  float64
#  22  child_score_item_23  11774 non-null  float64
# dtypes: float64(23)
# memory usage: 2.2 MB

# %%
domain_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11822 entries, 0 to 11821
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   child_domain_1  11822 non-null  float64
#  1   child_domain_2  11822 non-null  float64
#  2   child_domain_3  11822 non-null  float64
#  3   child_domain_4  11822 non-null  float64
#  4   child_domain_5  11822 non-null  float64
# dtypes: float64(5)
# memory usage: 554.2 KB

# %%
x_scores= scores_df.values
x_domain= domain_df.values

# %%
print(x_scores[:2])
# Out:
# [[2.91000009 2.06999993 0.         4.25       4.19999981 4.57999992
#   3.76999998 4.51000023 2.80999994 2.83999991 2.47000003 1.38
#   2.6500001  3.1099999  1.34000003 4.03000021 6.13999987 3.21000004
#   0.         2.47000003 2.4000001  2.19000006 2.97000003]
#  [2.91000009 1.         2.22000003 4.25       4.19999981 4.57999992
#   4.73999977 5.32999992 4.05000019 2.83999991 2.47000003 2.79999995
#   2.6500001  3.1099999  1.34000003 4.03000021 3.01999998 3.21000004
#   2.6400001  2.47000003 2.4000001  3.08999991 0.        ]]

# %%
print(x_domain[:2])
# Out:
# [[ 9.22999954 17.05999947 12.14999962 14.61999893 13.23999977]
#  [10.38000011 18.85000038 14.81000042 11.5        13.81000042]]

# %%
mx_scaler= MinMaxScaler()
scores_scaled = mx_scaler.fit_transform(x_scores)
domain_scaled = mx_scaler.fit_transform(x_domain)
mx_scores_scaled_df = pd.DataFrame(scores_scaled, columns=scores_df.columns)
mx_domain_scaled_df = pd.DataFrame(domain_scaled, columns=domain_df.columns)

# %%
st_scaler= StandardScaler()
scores_scaled = st_scaler.fit_transform(x_scores)
domain_scaled = st_scaler.fit_transform(x_domain)
st_scores_scaled_df = pd.DataFrame(scores_scaled, columns=scores_df.columns)
st_domain_scaled_df = pd.DataFrame(domain_scaled, columns=domain_df.columns)

# %%
x_scores_nan= np.isnan(x_scores)
x_scores[x_scores_nan]= 0
x_domain_nan= np.isnan(x_domain)
x_domain[x_domain_nan]= 0

nn_scaler= Normalizer()
scores_scaled = nn_scaler.fit_transform(x_scores)
domain_scaled = nn_scaler.fit_transform(x_domain)
nn_scores_scaled_df = pd.DataFrame(scores_scaled, columns=scores_df.columns)
nn_domain_scaled_df = pd.DataFrame(domain_scaled, columns=domain_df.columns)

# %%
mx_scores_scaled_df.head()
# Out:
#    child_score_item_1  child_score_item_2  child_score_item_3  \
# 0                 1.0            0.576602            0.000000
# 1                 1.0            0.278552            0.352381
# 2                 1.0            0.576602            0.000000
# 3                 1.0            0.000000            0.352381
# 4                 1.0            1.000000            0.352381
#
#    child_score_item_4  child_score_item_5  child_score_item_6  \
# 0            0.590278            1.000000                 1.0
# 1            0.590278            1.000000                 1.0
# 2            0.363889            0.740476                 0.0
# 3            0.000000            1.000000                 1.0
# 4            0.363889            0.740476                 0.0
#
#    child_score_item_7  child_score_item_8  child_score_item_9  \
# 0            0.795359            0.695988            0.466003
# 1            1.000000            0.822531            0.671642
# 2            0.795359            0.609568            0.000000
# 3            0.658228            0.526235            0.466003
# 4            0.795359            0.424383            0.466003
#
#    child_score_item_10  ...  child_score_item_14  child_score_item_15  \
# 0             0.629712  ...             1.000000             0.199405
# 1             0.629712  ...             1.000000             0.199405
# 2             0.000000  ...             0.321543             0.000000
# 3             0.629712  ...             1.000000             0.000000
# 4             0.000000  ...             1.000000             0.000000
#
#    child_score_item_16  child_score_item_17  child_score_item_18  \
# 0             1.000000             1.000000                  1.0
# 1             1.000000             0.491857                  1.0
# 2             1.000000             1.000000                  0.0
# 3             0.523573             1.000000                  1.0
# 4             1.000000             0.000000                  0.0
#
#    child_score_item_19  child_score_item_20  child_score_item_21  \
# 0              0.00000              0.72434             0.757098
# 1              0.77193              0.72434             0.757098
# 2              0.77193              0.72434             0.757098
# 3              0.77193              0.72434             0.394322
# 4              0.00000              0.72434             0.757098
#
#    child_score_item_22  child_score_item_23
# 0             0.708738             0.802703
# 1             1.000000             0.000000
# 2             0.708738             0.000000
# 3             0.000000             0.000000
# 4             1.000000             0.802703
#
# [5 rows x 23 columns]

# %%
st_scores_scaled_df.head()
# Out:
#    child_score_item_1  child_score_item_2  child_score_item_3  \
# 0            0.570777           -0.106195           -1.086458
# 1            0.570777           -0.981344            0.072437
# 2            0.570777           -0.106195           -1.086458
# 3            0.570777           -1.799240            0.072437
# 4            0.570777            1.137007            0.072437
#
#    child_score_item_4  child_score_item_5  child_score_item_6  \
# 0            0.957068            0.592810            1.425053
# 1            0.957068            0.592810            1.425053
# 2            0.208366           -0.625358           -0.701728
# 3           -0.995070            0.592810            1.425053
# 4            0.208366           -0.625358           -0.701728
#
#    child_score_item_7  child_score_item_8  child_score_item_9  \
# 0            0.383230            0.781848            0.563869
# 1            1.017617            1.469697            1.226187
# 2            0.383230            0.312097           -0.937029
# 3           -0.041876           -0.140877            0.563869
# 4            0.383230           -0.694511            0.563869
#
#    child_score_item_10  ...  child_score_item_14  child_score_item_15  \
# 0             1.329165  ...             1.001914            -0.288747
# 1             1.329165  ...             1.001914            -0.288747
# 2            -0.593910  ...            -0.767916            -0.883073
# 3             1.329165  ...             1.001914            -0.883073
# 4            -0.593910  ...             1.001914            -0.883073
#
#    child_score_item_16  child_score_item_17  child_score_item_18  \
# 0             1.363337             2.632399             1.296897
# 1             1.363337             0.711508             1.296897
# 2             1.363337             2.632399            -0.771071
# 3             0.115735             2.632399             1.296897
# 4             1.363337            -1.147816            -0.771071
#
#    child_score_item_19  child_score_item_20  child_score_item_21  \
# 0            -1.213140             0.269265             0.153991
# 1             0.545239             0.269265             0.153991
# 2             0.545239             0.269265             0.153991
# 3             0.545239             0.269265            -1.188137
# 4            -1.213140             0.269265             0.153991
#
#    child_score_item_22  child_score_item_23
# 0             0.064948             1.199051
# 1             0.865868            -0.767163
# 2             0.064948            -0.767163
# 3            -1.883958            -0.767163
# 4             0.865868             1.199051
#
# [5 rows x 23 columns]

# %%
nn_scores_scaled_df.head()
# Out:
#    child_score_item_1  child_score_item_2  child_score_item_3  \
# 0            0.189359            0.134699            0.000000
# 1            0.186717            0.064164            0.142444
# 2            0.240277            0.170918            0.000000
# 3            0.212765            0.000000            0.162316
# 4            0.242784            0.299517            0.185217
#
#    child_score_item_4  child_score_item_5  child_score_item_6  \
# 0            0.276555            0.273301            0.298029
# 1            0.272696            0.269488            0.293871
# 2            0.216332            0.256790            0.000000
# 3            0.000000            0.307084            0.334868
# 4            0.218589            0.259470            0.000000
#
#    child_score_item_7  child_score_item_8  child_score_item_9  \
# 0            0.245321            0.293474            0.182852
# 1            0.304137            0.341993            0.259864
# 2            0.311286            0.326149            0.000000
# 3            0.228120            0.249323            0.205454
# 4            0.314535            0.229435            0.234441
#
#    child_score_item_10  ...  child_score_item_14  child_score_item_15  \
# 0             0.184804  ...             0.202373             0.087196
# 1             0.182225  ...             0.199550             0.085980
# 2             0.000000  ...             0.082569             0.000000
# 3             0.207647  ...             0.227388             0.000000
# 4             0.000000  ...             0.259470             0.000000
#
#    child_score_item_16  child_score_item_17  child_score_item_18  \
# 0             0.262239             0.399541             0.208880
# 1             0.258580             0.193775             0.205966
# 2             0.332754             0.506975             0.000000
# 3             0.154273             0.448928             0.234700
# 4             0.336227             0.000000             0.000000
#
#    child_score_item_19  child_score_item_20  child_score_item_21  \
# 0             0.000000             0.160727             0.156172
# 1             0.169393             0.158485             0.153993
# 2             0.217983             0.203946             0.198166
# 3             0.193024             0.180595             0.091394
# 4             0.000000             0.206074             0.200234
#
#    child_score_item_22  child_score_item_23
# 0             0.142507             0.193263
# 1             0.198266             0.000000
# 2             0.180827             0.000000
# 3             0.000000             0.000000
# 4             0.257802             0.247790
#
# [5 rows x 23 columns]

# %%
def create_average(df, col_name):
    """
    
    """
    df[col_name]= df.iloc[:,:].mean(axis=1)
    return df[col_name]

# %%
data['score_item_scaled_average']= create_average(mx_scores_scaled_df, 'average')

# %%
data['child_domain_scaled_average']= create_average(mx_domain_scaled_df, 'average')

# %%
data[['score_item_scaled_average', 'child_domain_scaled_average']].apply(lambda x: round(x*10, 2))

# %%
X= data.drop(data.columns[9:37], axis=1)

# %%
X.columns[0:50]
# Out:
# Index(['child_id', 'data_year', 'data_source', 'child_date', 'child_age',
#        'child_enrolment_date', 'child_months_enrolment', 'child_grant',
#        'child_years_in_programme', 'child_age_group', 'child_zha',
#        'child_zha_w2', 'child_stunted', 'child_stunted_w2',
#        'PD_1_INT_total_elom_CHILD', 'PD_1_INT_domain_1_CHILD',
#        'PD_1_INT_domain_2_CHILD', 'PD_1_INT_domain_3_CHILD',
#        'PD_1_INT_domain_4_CHILD', 'PD_1_INT_domain_5_CHILD', 'PD_2_INT_CHILD',
#        'PD_4_INT_CHILD', 'PD_1_INT_total_elom_facility',
#        'PD_1_INT_domain_1_facility', 'PD_1_INT_domain_2_facility',
#        'PD_1_INT_domain_3_facility', 'PD_1_INT_domain_4_facility',
#        'PD_1_INT_domain_5_facility', 'PD_2_INT_pc_all_ontrack_facility',
#        'PD_3_INT_pc_ontrack_facility', 'PD_4_INT_composite_facility',
#        'PD_1_INT_total_elom_ward', 'PD_1_INT_domain_1_ward',
#        'PD_1_INT_domain_2_ward', 'PD_1_INT_domain_3_ward',
#        'PD_1_INT_domain_4_ward', 'PD_1_INT_domain_5_ward',
#        'PD_2_INT_pc_all_ontrack_ward', 'PD_3_INT_pc_ontrack_ward',
#        'PD_4_INT_composite_ward', 'PD_1_INT_total_elom_dc',
#        'PD_1_INT_domain_1_dc', 'PD_1_INT_domain_2_dc', 'PD_1_INT_domain_3_dc',
#        'PD_1_INT_domain_4_dc', 'PD_1_INT_domain_5_dc',
#        'PD_2_INT_pc_all_ontrack_dc', 'PD_3_INT_pc_ontrack_dc',
#        'PD_4_INT_composite_dc', 'PD_1_INT_total_elom_mn'],
#       dtype='object')

# %%
x_scores
# Out:
# array([[2.91000009, 2.06999993, 0.        , ..., 2.4000001 , 2.19000006,
#         2.97000003],
#        [2.91000009, 1.        , 2.22000003, ..., 2.4000001 , 3.08999991,
#         0.        ],
#        [2.91000009, 2.06999993, 0.        , ..., 2.4000001 , 2.19000006,
#         0.        ],
#        ...,
#        [2.9100001 , 2.0699999 , 2.22      , ..., 2.4000001 , 2.1900001 ,
#         2.97      ],
#        [2.91000009, 3.58999991, 6.30000019, ..., 2.4000001 , 3.08999991,
#         2.97000003],
#        [2.91000009, 3.58999991, 2.22000003, ..., 3.17000008, 2.19000006,
#         0.        ]])

# %%
a= scores_df.iloc[:, :].sum(axis=1)
b= domain_df.iloc[:, :].sum(axis=1)

# %%
a== b
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 11817    False
# 11818    False
# 11819    False
# 11820    False
# 11821    False
# Length: 11822, dtype: bool

# %%
a= a.apply(lambda x: round(x, 2))
b= b.apply(lambda x: round(x, 2))

# %%
a==b
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 11817    True
# 11818    True
# 11819    True
# 11820    True
# 11821    True
# Length: 11822, dtype: bool

# %%
n = 0
check= []
check2= []

for i in range(len(a)):
    if a[i]!= b[i]:
        check.append(a[i])
        check2.append(a[i]-b[i])

# %%
check3= [(i**2)**0.5 for i in check2]

print(f'%difference= {round(len(check)/len(a)*100, 2)}%.\n\
Total of different= {len(check)}\nAverage= {np.mean(check3)}\n')
# Out:
# %difference= 19.64%.
# Total of different= 2322
# Average= 0.431937984496124

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# visual asessment of the didstribution of the data

plt.figure(figsize=[15, 5])
plt.subplot(1,2,1)
arr= plt.hist(data= data, x='score_item_scaled_average', bins=5)
plt.title('Distribution of MinMaxScaled Scores Items with a binsoze of 5.')
plt.xlabel('Scaled Scores')
plt.ylabel('count')
for i in range(5):
    plt.text(arr[1][i]+0.05,arr[0][i]+50,str(arr[0][i]))

plt.subplot(1,2,2)
arr= plt.hist(data= data, x='score_item_scaled_average', bins=10)
plt.title('Distribution of MinMaxScaled Scores Items with a binsoze of 10.')
plt.xlabel('Scaled Scores')
plt.ylabel('count')
for i in range(10):
    plt.text(arr[1][i]+0.02,arr[0][i]+25,str(arr[0][i]))

plt.tight_layout()

# %%
from sklearn.preprocessing import LabelEncoder
lb= LabelEncoder()

n_bins= 5 # change this value to change number of y labels categories
y_cat= lb.fit_transform(pd.cut(data['score_item_scaled_average'], n_bins, retbins=True)[0])

# %%
# viewing min and max values of y
print(f'max y value: {y_cat.max()}\nMin y value: {y_cat.min()}')
# Out:
# max y value: 4
# Min y value: 0

# %%
# adjusting the y values to start at 1 and end at
y_cat= y+1

# %%
# viewing min and max values of y
print(f'max y value: {y_cat.max()}\nMin y value: {y_cat.min()}')
y_cat
# Out:
# max y value: 6
# Min y value: 2
# array([5, 5, 4, ..., 5, 5, 5])

# %%
y_cont=np.array(data['score_item_scaled_average'].apply(lambda x: round(x, 4)))

# %%
y_cont
# Out:
# array([0.698 , 0.735 , 0.472 , ..., 0.6075, 0.6913, 0.6758])
